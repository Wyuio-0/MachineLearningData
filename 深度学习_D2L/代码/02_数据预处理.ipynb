# %%
import os

os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n') # 列名
    f.write('NA,Pave,127500\n') # 每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
# 如果没有安装pandas，只需取消对以下行的注释来安装pandas
# !pip install pandas
# !python.exe -m pip install --upgrade pip
import pandas as pd

data = pd.read_csv(data_file)
print(data)
# Out:
# Requirement already satisfied: pandas in D:\Python\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in D:\Python\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in D:\Python\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in D:\Python\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in D:\Python\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pip in D:\Python\Lib\site-packages (26.2.1)
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
inputs = inputs.fillna(inputs.mean(numeric_only=True))
print(inputs)
print(outputs)
# Out:
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN
# 0    127500
# 1    106000
# 2    178100
# 3    140000
# Name: Price, dtype: int64

# %%
inputs = pd.get_dummies(inputs, dummy_na=True)
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0       3.0        True      False
# 1       2.0       False       True
# 2       4.0       False       True
# 3       3.0       False       True

# %%
import torch
X = torch.tensor(inputs.to_numpy(dtype=float))
y = torch.tensor(outputs.to_numpy(dtype=float))
X, y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([127500., 106000., 178100., 140000.], dtype=torch.float64))
